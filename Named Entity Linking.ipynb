# %% [markdown]
# # Named Entity Linking
#
# A crucial part of question answering over knowledge graphs is identification of named entities in the question, and disambiguating and linking them to the corresponding ID in the KG. There are two challenges: recognizing strings as named entities, and finding the intended entity in the KG.
#
# In Spacy, we can use the built-in entity annotation layer for entity recognition. Also, there are various options to integrate entity linking in the spacy annotation pipeline. We explore these options below, with wikidata as KG. In all experiments, we use a set of 50 questions about the movies and actors as test data. All experiments done with Spacy 3.1
#
# ### Loading Spacy
#
# We noticed a problem with Spacy sentence segmentation when applied to sentences containing movie titles. Titles such as *'Doctor Who'* or *'O Brother Where Art Thou'* can confuse the sentence segmenter and may lead to Spacy to think that somewhere in the title a new sentence starts. To avoid this problem, and as we already know that each input is exactly one sentence, we use the custom splitter below as suggested by the Spacy documentation.

# %%
import spacy

# https://spacy.io/usage/processing-pipelines#custom-components
# add this for custom sentence segmentation that does never split the input  question

from spacy.language import Language

@Language.component("custom_sentencizer")
def custom_sentencizer(doc):
    for i, token in enumerate(doc):
        if i == 0:
            doc[i].is_sent_start = True
        else:
            # Explicitly set sentence start to False otherwise, to tell
            # the parser to leave those tokens alone
            doc[i].is_sent_start = False
    return doc

nlp = spacy.load('en_core_web_lg')

nlp.add_pipe("custom_sentencizer", before="parser")  # Insert before the parser
# Out:
# <function __main__.custom_sentencizer(doc)>

# %% [markdown]
# ### Spacy Named Entity Recognition
#
# First, we test the NER component, i.e. which entities are recognized by a standard Spacy model (lg)?
#
# The lg model does a reasonable job at recognizing NEs although a few are missed as well. The easiest way to improve coverage is to add manual patterns, as explained below. Another option is to try the transformer model (tf), which in many ways is more accurate than the lg model.

# %%
with open('test_all1.csv')  as questions :
    for line in questions :
        (id, question) = line.strip().split('\t')
        doc = nlp(question)
        for sent in doc.sents :
            print(sent.text)
            for ent in sent.ents:
                print(ent.text)
        print()
# Out:
# Who directed Tenet?
# Tenet
#
# Who directed Bad Times at the El Royale?
#
# Who wrote the music for Once Upon a Time in the West?
# Once Upon a Time
# West
#
# Which streaming service is the distributor of Tiger King?
# Tiger King
#
# What is the country of origin of The Intouchables?
# Intouchables
#
# When did John Hamilton die?
# John Hamilton
#
# Where did Alan Rickman die?
# Alan Rickman
#
# In which year was The Truman Show released?
# which year
# The Truman Show
#
# What is the box office ranking of the movie Inception?
#
# Inception was directed by whom?
#
# By whom was Jaws directed?
#
# What is Michael Cera's place of birth?
# Michael Cera's
#
# Walt Disney Animation Studios was founded by whom?
# Walt Disney Animation Studios
#
# What is the catchphrase of the fictional character James Bond?
# James Bond
#
# What is the main subject of Se7en?
#
# What are the genres of Fargo?
# Fargo
#
# Who are the directors of The Big Lebowski?
#
# Who are Christopher Nolan's children?
# Christopher Nolan's
#
# Which movies did Jan de Bont direct?
# Jan de Bont
#
# What awards did Alan Rickman receive?
# Alan Rickman
#
# What are the occupations of John Hamilton?
# John Hamilton
#
# Who wrote the scenario for Wall Street?
#
# Who are the directors of Shrek?
# Shrek
#
# What are the main subjects of Inception?
#
# Which countries is the movie O Brother Where Art Thou from?
#
# What gender is Elliot Page?
# Elliot Page
#
# Name the children of Will Smith.
# Will Smith
#
# How many episodes does The Queen's Gambit have?
# The Queen's
#
# How many children does Brad Pitt have?
# Brad Pitt
#
# What is the number of screenwriters of the animated adventure film Tarzan?
# Tarzan
#
# How many awards has Marilyn Monroe received?
# Marilyn Monroe
#
# How many episodes does Friends have?
#
# Who plays the Joker in the movie Joker?
# Joker
# Joker
#
# Who plays The Dude in The Big Lebowski?
#
# When was Evan Almighty released in Germany?
# Evan
# Germany
#
# When did the TV-series Doctor Who first start?
# first
#
# What character does Cobie Smulders play in How I Met Your Mother?
# Cobie Smulders
# How I Met Your Mother
#
# In what films did Anthony Hopkins play Hannibal Lecter?
# Anthony Hopkins
# Hannibal Lecter
#
# Who won the Oscar for best director in 2020?
# Oscar
# 2020
#
# Is The Dawn Wall a documentary film?
# The Dawn Wall
#
# Is Jeff Bridges a cast member of The Wolf of Wall Street?
# Jeff Bridges
# The Wolf of Wall Street
#
# Did George Clooney win the BAFTA Award for Best Film?
# George Clooney
# the BAFTA Award for Best Film
#
# Is Shrek a fantasy film?
# Shrek
#
# Does Eddard Stark have children?
# Eddard Stark
#
# Is Finn Collins female?
# Finn Collins
#
# Who is Jeff Bridges?
# Jeff Bridges
#
# What is the date of birth of the son of Denzel Washington?
# Denzel Washington
#
# What is an aerial shot?
#
# When was the actor Joaquin Phoenix born?
# Joaquin Phoenix
#
# What is the length of Speed?

# %% [markdown]
# ## Entity linking with the wikidata entity finder api
#
# For entity linking, you can use the wikidata api for finding the corresponding entity IDs. Note that the api can give multiple results for a given text string. Here, we simply return the id of the first result. Apart from id, the api also returns a label and description for each match, that could perhaps be used for disambiguation. (Ie prefer entities with certain keywords in the description field, like *actor, film, ....*
#
# Integration with Spacy is done by introducing an extension attribute on the spans found by NER. See https://spacy.io/usage/rule-based-matching#entityruler for an example and discussion.

# %%
import requests

from spacy.tokens import Span
    
def wikidata_entity_link(span) :
    url = 'https://www.wikidata.org/w/api.php'
    params = {'action':'wbsearchentities', 
              'language':'en',
              'format':'json',
              'search': span.text}
    json = requests.get(url,params).json()
    # this part can be replaced by fancier disambiguation methods, or returning a list of ids from all search results
    try : 
        wd_id = json['search'][0]['id']
    except IndexError :
        wd_id = 'no_id_found'
    return wd_id
            
Span.set_extension('wikidata_id',getter=wikidata_entity_link)    

with open('test_all1.csv')  as questions :
    for line in questions :
        (id, question) = line.strip().split('\t')
        doc = nlp(question)
        for sent in doc.sents :
            print(sent.text)
        for ent in doc.ents:
            print(ent.text, ent._.wikidata_id)
        print()
# Out:
# Who directed Tenet?
# Tenet Q63985561
#
# Who directed Bad Times at the El Royale?
#
# Who wrote the music for Once Upon a Time in the West?
# Once Upon a Time Q23673
# West Q679
#
# Which streaming service is the distributor of Tiger King?
# Tiger King Q88306935
#
# What is the country of origin of The Intouchables?
# Intouchables Q595
#
# When did John Hamilton die?
# John Hamilton Q46648449
#
# Where did Alan Rickman die?
# Alan Rickman Q106481
#
# In which year was The Truman Show released?
# which year no_id_found
# The Truman Show Q214801
#
# What is the box office ranking of the movie Inception?
#
# Inception was directed by whom?
#
# By whom was Jaws directed?
#
# What is Michael Cera's place of birth?
# Michael Cera's no_id_found
#
# Walt Disney Animation Studios was founded by whom?
# Walt Disney Animation Studios Q1047410
#
# What is the catchphrase of the fictional character James Bond?
# James Bond Q844
#
# What is the main subject of Se7en?
#
# What are the genres of Fargo?
# Fargo Q34109
#
# Who are the directors of The Big Lebowski?
#
# Who are Christopher Nolan's children?
# Christopher Nolan's no_id_found
#
# Which movies did Jan de Bont direct?
# Jan de Bont Q376107
#
# What awards did Alan Rickman receive?
# Alan Rickman Q106481
#
# What are the occupations of John Hamilton?
# John Hamilton Q46648449
#
# Who wrote the scenario for Wall Street?
#
# Who are the directors of Shrek?
# Shrek Q483815
#
# What are the main subjects of Inception?
#
# Which countries is the movie O Brother Where Art Thou from?
#
# What gender is Elliot Page?
# Elliot Page Q173399
#
# Name the children of Will Smith.
# Will Smith Q40096
#
# How many episodes does The Queen's Gambit have?
# The Queen's Q877925
#
# How many children does Brad Pitt have?
# Brad Pitt Q35332
#
# What is the number of screenwriters of the animated adventure film Tarzan?
# Tarzan Q170241
#
# How many awards has Marilyn Monroe received?
# Marilyn Monroe Q4616
#
# How many episodes does Friends have?
#
# Who plays the Joker in the movie Joker?
# Joker Q217533
# Joker Q217533
#
# Who plays The Dude in The Big Lebowski?
#
# When was Evan Almighty released in Germany?
# Evan Q5254911
# Germany Q183
#
# When did the TV-series Doctor Who first start?
# first Q28084844
#
# What character does Cobie Smulders play in How I Met Your Mother?
# Cobie Smulders Q200566
# How I Met Your Mother Q147235
#
# In what films did Anthony Hopkins play Hannibal Lecter?
# Anthony Hopkins Q65932
# Hannibal Lecter Q211013
#
# Who won the Oscar for best director in 2020?
# Oscar Q9941
# 2020 Q25337
#
# Is The Dawn Wall a documentary film?
# The Dawn Wall Q56604528
#
# Is Jeff Bridges a cast member of The Wolf of Wall Street?
# Jeff Bridges Q174843
# The Wolf of Wall Street Q1392744
#
# Did George Clooney win the BAFTA Award for Best Film?
# George Clooney Q23844
# the BAFTA Award for Best Film no_id_found
#
# Is Shrek a fantasy film?
# Shrek Q483815
#
# Does Eddard Stark have children?
# Eddard Stark Q259818
#
# Is Finn Collins female?
# Finn Collins Q96946710
#
# Who is Jeff Bridges?
# Jeff Bridges Q174843
#
# What is the date of birth of the son of Denzel Washington?
# Denzel Washington Q42101
#
# What is an aerial shot?
#
# When was the actor Joaquin Phoenix born?
# Joaquin Phoenix Q185140
#
# What is the length of Speed?

# %% [markdown]
# ### Using the entity ruler
#
# For entities not recognized by the built-in NER component, we can provide a manually compiled list of patterns. If we add these using the entity_ruler pipeline component, it will integrate with the built-in NER component using the logic described in the documentation (ie the ruler takes precedence over built-in ner normally, but other options are possible). Another nice feature is that the extension attribute wikidata_id is also set for entities recognized by the entity_ruler.
#
# https://spacy.io/usage/rule-based-matching#entityruler
#
# In the example below, for instance, _Bad Times at the El Royale_ is recognized as entity, and a wikidata_id is added. Also, _Once Upon a Time in the West_ is no longer broken in two entities, but recognized as a single entity (i.e. the manual patters override the built-in ner).
#
# The challenge is of course to think of robust methods for creating pattern files for a given domain and application.

# %%
nlp.add_pipe("entity_ruler",first=True).\
       from_disk('./movie_patterns.jsonl')

with open('test_all1.csv')  as questions :
    for line in questions :
        (id, question) = line.strip().split('\t')
        doc = nlp(question)
        for sent in doc.sents :
            print(sent.text)
        for ent in doc.ents:
            print(ent.text, ent._.wikidata_id)
        print()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-4648a674714d> in <module>
# ----> 1 nlp.add_pipe("entity_ruler",first=True).\
#       2        from_disk('./movie_patterns.jsonl')
#       3
#       4 with open('test_all1.csv')  as questions :
#       5     for line in questions :
#
# ~/.local/lib/python3.8/site-packages/spacy/language.py in add_pipe(self, factory_name, name, before, after, first, last, source, config, raw_config, validate)
#     774         name = name if name is not None else factory_name
#     775         if name in self.component_names:
# --> 776             raise ValueError(Errors.E007.format(name=name, opts=self.component_names))
#     777         if source is not None:
#     778             # We're loading the component from a model. After loading the
#
# ValueError: [E007] 'entity_ruler' already exists in pipeline. Existing names: ['entity_ruler', 'tok2vec', 'tagger', 'custom_sentencizer', 'parser', 'senter', 'attribute_ruler', 'lemmatizer', 'ner']

# %% [markdown]
# ## Uising Existing Entity Linkers with Spacy
#
# There are two modules that can be added to the Spacy pipeline to also do entity linking with Wikidata as knowledge base.
#
# ### Entity Linker
#
# This module uses a dump of wikidata to create a database with labels and ids. Disambiguation is not context-sensitive but takes the most referred to id as answer (as does the wikidata api), so this is very comparable to the wikidata api, but using a static db instead of an api.
#
# More details here: [spacy entity linker](https://pypi.org/project/spacy-entity-linker/)
#
# Overall, it does a reasonable good job, but added value over the solution presented above is unclear. I.e. are there cases which this linker finds or resolves better than the wikidata api?) One case in point are genetives (*Christopher Nolan's*) which are dealt with correctly by this entity linker (ie probably by stripping the genetive s before consulting the database), but this feature can easily be integrated in the get_wikidata_api as well.

# %%
nlp_el = spacy.load('en_core_web_lg')

nlp_el.add_pipe("custom_sentencizer", before="parser")  # Insert before the parser


nlp_el.add_pipe("entityLinker", last=True)

# %%
with open('test_all1.csv')  as questions :
    for line in questions :
        (id, question) = line.strip().split('\t')
        print(question)
        doc = nlp_el(question)
        for sent in doc.sents :
            sent._.linkedEntities.pretty_print()
        print()
# Out:
# Who directed Tenet?
# <EntityElement: https://www.wikidata.org/wiki/Q63985561 Tenet                     2020 film by Christopher Nolan                    >
#
# Who directed Bad Times at the El Royale?
# <EntityElement: https://www.wikidata.org/wiki/Q4840445 Bad Times                                                                   >
# <EntityElement: https://www.wikidata.org/wiki/Q5352061 El Royale                 El Royal  the movie                               >
#
# Who wrote the music for Once Upon a Time in the West?
# <EntityElement: https://www.wikidata.org/wiki/Q638 music                     form of art using sound                           >
# <EntityElement: https://www.wikidata.org/wiki/Q43297 Time                      American weekly news magazine                     >
# <EntityElement: https://www.wikidata.org/wiki/Q313498 Benjamin West             Anglo-American painter                            >
#
# Which streaming service is the distributor of Tiger King?
# <EntityElement: https://www.wikidata.org/wiki/Q44127 server                    computer program or device that provides access to a central resource or other functionality for cli>
# <EntityElement: https://www.wikidata.org/wiki/Q1459069 distributor               device in the ignition system of an internal combustion engine>
# <EntityElement: https://www.wikidata.org/wiki/Q10993 Tiger Woods               American golfer                                   >
#
# What is the country of origin of The Intouchables?
# <EntityElement: https://www.wikidata.org/wiki/Q3336843 country within the United Kingdom one of four constituent parts of the United Kingdom:  England, Wales, Scotland and Northern Ireland>
# <EntityElement: https://www.wikidata.org/wiki/Q7376362 river source              starting point of a river                         >
# <EntityElement: https://www.wikidata.org/wiki/Q595 The Intouchables          2011 French film directed by Olivier Nakache and Éric Toledano>
#
# When did John Hamilton die?
# <EntityElement: https://www.wikidata.org/wiki/Q6226112 John Church Hamilton      American historian, son of Alexander Hamilton     >
#
# Where did Alan Rickman die?
# <EntityElement: https://www.wikidata.org/wiki/Q106481 Alan Rickman              English film, television and stage actor          >
#
# In which year was The Truman Show released?
# <EntityElement: https://www.wikidata.org/wiki/Q577 year                      orbital period of the Earth around the Sun        >
# <EntityElement: https://www.wikidata.org/wiki/Q214801 The Truman Show           1998 film directed by Peter Weir                  >
#
# What is the box office ranking of the movie Inception?
# <EntityElement: https://www.wikidata.org/wiki/Q526719 ranking                   relationship between items in a set               >
# <EntityElement: https://www.wikidata.org/wiki/Q11424 film                      sequence of images that give the impression of movement>
# <EntityElement: https://www.wikidata.org/wiki/Q25188 Inception                 2010 science fiction film directed by Christopher Nolan>
#
# Inception was directed by whom?
# <EntityElement: https://www.wikidata.org/wiki/Q25188 Inception                 2010 science fiction film directed by Christopher Nolan>
#
# By whom was Jaws directed?
# <EntityElement: https://www.wikidata.org/wiki/Q189505 Jaws                      2014 American thriller film directed by Steven Spielberg>
#
# What is Michael Cera's place of birth?
# <EntityElement: https://www.wikidata.org/wiki/Q1322263 place of birth            place where a person is born                      >
# <EntityElement: https://www.wikidata.org/wiki/Q309555 Michael Cera              Canadian actor                                    >
# <EntityElement: https://www.wikidata.org/wiki/Q34581 childbirth                expulsion of a fetus from the pregnant mother's uterus>
#
# Walt Disney Animation Studios was founded by whom?
# <EntityElement: https://www.wikidata.org/wiki/Q1047410 Walt Disney Animation Studios one of the Walt Disney Company's animation studios>
#
# What is the catchphrase of the fictional character James Bond?
# <EntityElement: https://www.wikidata.org/wiki/Q2708515 catchphrase               phrase or expression recognized by its repeated utterance>
# <EntityElement: https://www.wikidata.org/wiki/Q95074 fictional character       fictional human or non-human character in a narrative work of arts (for human fictional character us>
# <EntityElement: https://www.wikidata.org/wiki/Q844 James Bond                Media franchise about a British spy               >
#
# What is the main subject of Se7en?
# <EntityElement: https://www.wikidata.org/wiki/Q164573 subject                   linguistics: word or phrase which controls the verb in the clause; one of the two main constituents >
# <EntityElement: https://www.wikidata.org/wiki/Q190908 Seven                     1995 neo-noir crime thriller film by David Fincher>
#
# What are the genres of Fargo?
# <EntityElement: https://www.wikidata.org/wiki/Q188451 music genre               category that identifies pieces of music as belonging to a shared tradition or set of conventions>
# <EntityElement: https://www.wikidata.org/wiki/Q15931555 Fargo                     American dark comedy-crime drama television series>
#
# Who are the directors of The Big Lebowski?
# <EntityElement: https://www.wikidata.org/wiki/Q2526255 film director             occupation of a person who directs a film         >
# <EntityElement: https://www.wikidata.org/wiki/Q337078 The Big Lebowski          1998 film by Joel Coen, Ethan Coen                >
#
# Who are Christopher Nolan's children?
# <EntityElement: https://www.wikidata.org/wiki/Q7569 child                     human between the stages of birth and puberty     >
# <EntityElement: https://www.wikidata.org/wiki/Q25191 Christopher Nolan         English-American film director, screenwriter, and producer>
#
# Which movies did Jan de Bont direct?
# <EntityElement: https://www.wikidata.org/wiki/Q11424 film                      sequence of images that give the impression of movement>
# <EntityElement: https://www.wikidata.org/wiki/Q376107 Jan de Bont               Dutch film director                               >
# <EntityElement: https://www.wikidata.org/wiki/Q183 Germany                   federal parliamentary republic in central-western Europe>
#
# What awards did Alan Rickman receive?
# <EntityElement: https://www.wikidata.org/wiki/Q618779 award                     something given to a person or a group of people to recognize their excellence in a certain field>
# <EntityElement: https://www.wikidata.org/wiki/Q106481 Alan Rickman              English film, television and stage actor          >
#
# What are the occupations of John Hamilton?
# <EntityElement: https://www.wikidata.org/wiki/Q28640 profession                vocation founded upon specialized educational training>
# <EntityElement: https://www.wikidata.org/wiki/Q6226112 John Church Hamilton      American historian, son of Alexander Hamilton     >
#
# Who wrote the scenario for Wall Street?
# <EntityElement: https://www.wikidata.org/wiki/Q103076 screenplay                written work by screenwriters for a film or television program>
# <EntityElement: https://www.wikidata.org/wiki/Q11690 Wall Street               street in Manhattan                               >
#
# Who are the directors of Shrek?
# <EntityElement: https://www.wikidata.org/wiki/Q2526255 film director             occupation of a person who directs a film         >
# <EntityElement: https://www.wikidata.org/wiki/Q483815 Shrek                     2001 film directed by Andrew Adamson and Vicky Jenson>
#
# What are the main subjects of Inception?
# <EntityElement: https://www.wikidata.org/wiki/Q164573 subject                   linguistics: word or phrase which controls the verb in the clause; one of the two main constituents >
# <EntityElement: https://www.wikidata.org/wiki/Q25188 Inception                 2010 science fiction film directed by Christopher Nolan>
#
# Which countries is the movie O Brother Where Art Thou from?
# <EntityElement: https://www.wikidata.org/wiki/Q6256 country                   distinct region in geography; a broad term that can include political divisions or regions associate>
# <EntityElement: https://www.wikidata.org/wiki/Q11424 film                      sequence of images that give the impression of movement>
# <EntityElement: https://www.wikidata.org/wiki/Q990804 Brother Industries        Japanese multinational electronics and electrical equipment company>
# <EntityElement: https://www.wikidata.org/wiki/Q1239456 Art                       French language play by Yasmina Reza              >
#
# What gender is Elliot Page?
# <EntityElement: https://www.wikidata.org/wiki/Q48277 gender                    range of physical, mental, and behavioral characteristics distinguishing between masculinity and fem>
# <EntityElement: https://www.wikidata.org/wiki/Q4934 Larry Page                American computer scientist and Internet entrepreneur>
#
# Name the children of Will Smith.
# <EntityElement: https://www.wikidata.org/wiki/Q7569 child                     human between the stages of birth and puberty     >
# <EntityElement: https://www.wikidata.org/wiki/Q40096 Will Smith                American actor, film producer, and rapper         >
#
# How many episodes does The Queen's Gambit have?
# <EntityElement: https://www.wikidata.org/wiki/Q1983062 episode                   part of a work such as a serial television or radio drama>
# <EntityElement: https://www.wikidata.org/wiki/Q2639150 Gambit                    comic book character                              >
# <EntityElement: https://www.wikidata.org/wiki/Q9682 Elizabeth II              queen of the UK, Canada, Australia, and New Zealand, and head of the Commonwealth of Nations>
#
# How many children does Brad Pitt have?
# <EntityElement: https://www.wikidata.org/wiki/Q7569 child                     human between the stages of birth and puberty     >
# <EntityElement: https://www.wikidata.org/wiki/Q35332 Brad Pitt                 American actor and filmmaker                      >
#
# What is the number of screenwriters of the animated adventure film Tarzan?
# <EntityElement: https://www.wikidata.org/wiki/Q11563 number                    mathematical object used to count, label, and measure>
# <EntityElement: https://www.wikidata.org/wiki/Q28389 screenwriter              writer who writes for TV, films, comics and games >
# <EntityElement: https://www.wikidata.org/wiki/Q319221 adventure film            film genre                                        >
# <EntityElement: https://www.wikidata.org/wiki/Q208696 Tarzan                    1999 American animated adventure film produced by Walt Disney Feature Animation>
#
# How many awards has Marilyn Monroe received?
# <EntityElement: https://www.wikidata.org/wiki/Q618779 award                     something given to a person or a group of people to recognize their excellence in a certain field>
# <EntityElement: https://www.wikidata.org/wiki/Q4616 Marilyn Monroe            American actress, model, and singer               >
#
# How many episodes does Friends have?
# <EntityElement: https://www.wikidata.org/wiki/Q1983062 episode                   part of a work such as a serial television or radio drama>
# <EntityElement: https://www.wikidata.org/wiki/Q79784 Friends                   American sitcom (1994–2004)                       >
#
# Who plays the Joker in the movie Joker?
# <EntityElement: https://www.wikidata.org/wiki/Q42759035 Joker                     2019 film by Todd Phillips                        >
# <EntityElement: https://www.wikidata.org/wiki/Q11424 film                      sequence of images that give the impression of movement>
# <EntityElement: https://www.wikidata.org/wiki/Q42759035 Joker                     2019 film by Todd Phillips                        >
#
# Who plays The Dude in The Big Lebowski?
# <EntityElement: https://www.wikidata.org/wiki/Q22078004 Dude                      2018 film by Olivia Milch                         >
# <EntityElement: https://www.wikidata.org/wiki/Q337078 The Big Lebowski          1998 film by Joel Coen, Ethan Coen                >
#
# When was Evan Almighty released in Germany?
# <EntityElement: https://www.wikidata.org/wiki/Q5254911 Evan                      male given name                                   >
# <EntityElement: https://www.wikidata.org/wiki/Q183 Germany                   federal parliamentary republic in central-western Europe>
#
# When did the TV-series Doctor Who first start?
# <EntityElement: https://www.wikidata.org/wiki/Q170198 series                    sequence of partial sums of a given mathematical sequence>
#
# What character does Cobie Smulders play in How I Met Your Mother?
# <EntityElement: https://www.wikidata.org/wiki/Q32483 character                 primitive data type                               >
# <EntityElement: https://www.wikidata.org/wiki/Q200566 Cobie Smulders            Canadian actress and former model                 >
# <EntityElement: https://www.wikidata.org/wiki/Q25339558 mother!                   2017 film by Darren Aronofsky                     >
#
# In what films did Anthony Hopkins play Hannibal Lecter?
# <EntityElement: https://www.wikidata.org/wiki/Q11424 film                      sequence of images that give the impression of movement>
# <EntityElement: https://www.wikidata.org/wiki/Q65932 Anthony Hopkins           Welsh actor                                       >
# <EntityElement: https://www.wikidata.org/wiki/Q211013 Hannibal Lecter           fictional character                               >
#
# Who won the Oscar for best director in 2020?
# <EntityElement: https://www.wikidata.org/wiki/Q9941 O                         letter of the Latin alphabet                      >
# <EntityElement: https://www.wikidata.org/wiki/Q2526255 film director             occupation of a person who directs a film         >
#
# Is The Dawn Wall a documentary film?
# <EntityElement: https://www.wikidata.org/wiki/Q42101185 Dawn                      South Korean singer                               >
# <EntityElement: https://www.wikidata.org/wiki/Q93204 documentary film          nonfictional motion picture                       >
#
# Is Jeff Bridges a cast member of The Wolf of Wall Street?
# <EntityElement: https://www.wikidata.org/wiki/Q174843 Jeff Bridges              American actor, singer-songwriter and producer    >
# <EntityElement: https://www.wikidata.org/wiki/Q379825 element                   any one of the distinct objects that make up a set in set theory>
# <EntityElement: https://www.wikidata.org/wiki/Q1392744 The Wolf of Wall Street   2013 film directed by Martin Scorsese             >
# <EntityElement: https://www.wikidata.org/wiki/Q11690 Wall Street               street in Manhattan                               >
#
# Did George Clooney win the BAFTA Award for Best Film?
# <EntityElement: https://www.wikidata.org/wiki/Q23844 George Clooney            American actor, filmmaker, and activist           >
# <EntityElement: https://www.wikidata.org/wiki/Q732997 British Academy Film Awards annual award show hosted by the British Academy of Film and Television Arts>
# <EntityElement: https://www.wikidata.org/wiki/Q56474015 Jungleland                Film                                              >
#
# Is Shrek a fantasy film?
# <EntityElement: https://www.wikidata.org/wiki/Q483815 Shrek                     2001 film directed by Andrew Adamson and Vicky Jenson>
# <EntityElement: https://www.wikidata.org/wiki/Q157394 fantasy film              film genre                                        >
#
# Does Eddard Stark have children?
# <EntityElement: https://www.wikidata.org/wiki/Q259818 Eddard Stark              character in A Song of Ice and Fire               >
# <EntityElement: https://www.wikidata.org/wiki/Q7569 child                     human between the stages of birth and puberty     >
#
# Is Finn Collins female?
# <EntityElement: https://www.wikidata.org/wiki/Q43445 female organism           plant or animal which is female                   >
#
# Who is Jeff Bridges?
# <EntityElement: https://www.wikidata.org/wiki/Q174843 Jeff Bridges              American actor, singer-songwriter and producer    >
#
# What is the date of birth of the son of Denzel Washington?
# <EntityElement: https://www.wikidata.org/wiki/Q654810 dating                    process of interacting and meeting other people on the prospect of establishing a romantic relations>
# <EntityElement: https://www.wikidata.org/wiki/Q34581 childbirth                expulsion of a fetus from the pregnant mother's uterus>
# <EntityElement: https://www.wikidata.org/wiki/Q177232 son                       male offspring; a boy or man in relation to his parents>
# <EntityElement: https://www.wikidata.org/wiki/Q42101 Denzel Washington         American actor, screenwriter, director and producer>
#
# What is an aerial shot?
# <EntityElement: https://www.wikidata.org/wiki/Q191839 aerial photography        taking images of the ground from the air          >
#
# When was the actor Joaquin Phoenix born?
# <EntityElement: https://www.wikidata.org/wiki/Q33999 actor                     person who acts in a dramatic or comic production and works in film, television, theatre, or radio>
# <EntityElement: https://www.wikidata.org/wiki/Q185140 Joaquin Phoenix           American actor, music video director, producer, musician, and social activist>
#
# What is the length of Speed?
# <EntityElement: https://www.wikidata.org/wiki/Q36253 length                    measured dimension of an object in a physical space>
# <EntityElement: https://www.wikidata.org/wiki/Q108006 Speed                     1994 American action-thriller film directed by Jan de Bont>

# %% [markdown]
# ## OpenTapioca
#
# A second option is the opentapioca named entity linker described [here](https://opentapioca.org/), integrated in spacy as part of the pipeline. As far as I can see, it builds on spacy named entity recognizer, and then adds the wikidata links for those.
#
# It does have a few issues :
#
# * tends to include question words as entities
# * misses all movie titles (recongizes Wall Street but as the actual stock exchange)
# * misses some actor names
# * does not always find the wikidata id (for instance, Brad Pitt is not assigned an ID, eventhough description is there?
#
# The problems with the NER could perhaps be solved by also including a manual entity-ruler component (assuing tapioca indeed iterates over all ents found by the spacy pipeline).
#
# Nevertheless, and in spite of being based on a context-sensitive disambiguation model, it seems to do a worse job than the options mentioned above.

# %%
#import spacy 
#nlp = spacy.blank('en')
nlp_tap = spacy.load('en_core_web_lg')

nlp_tap.add_pipe("custom_sentencizer", before="parser")  # Insert before the parser

nlp_tap.add_pipe('opentapioca')

# %%
with open('test_all1.csv') as questions :
    for line in questions:
        (id,question) = line.strip().split('\t')
        doc = nlp_tap(question)
        print(question)
        for span in doc.ents:
            print((span.text, span.kb_id_, span.label_, span._.description, span._.score))
        print()
# Out:
# Who directed Tenet?
# ('Tenet', '', 'ORG', 'American-Canadian heavy metal band', -0.7947068485334838)
#
# Who directed Bad Times at the El Royale?
#
# Who wrote the music for Once Upon a Time in the West?
# ('the West', 'Q160381', 'LOC', 'countries that identify themselves with an originally European', 0.13677535018577103)
#
# Which streaming service is the distributor of Tiger King?
# ('Tiger King', '', 'PERSON', 'American zoo operator, internet personality, musician, and cult leader.', -0.02800093594267583)
#
# What is the country of origin of The Intouchables?
# ('Intouchables', '', 'PERSON', None, None)
#
# When did John Hamilton die?
# ('When', 'Q7992417', 'ORG', None, 0.3903881669222681)
# ('John Hamilton', '', 'PERSON', 'English navy commander (1820–1864)', -0.5938130589979281)
# ('die', 'Q1210678', 'ORG', 'band', 0.4659305230980987)
#
# Where did Alan Rickman die?
# ('Alan Rickman', 'Q106481', 'PERSON', 'English film, television and stage actor, graphic designer (1946-2016)', 0.3719371138702773)
#
# In which year was The Truman Show released?
# ('which year', '', 'DATE', None, None)
# ('The Truman Show', '', 'WORK_OF_ART', None, None)
#
# What is the box office ranking of the movie Inception?
#
# Inception was directed by whom?
#
# By whom was Jaws directed?
#
# What is Michael Cera's place of birth?
# ("Michael Cera's", 'Q309555', 'PERSON', 'Canadian actor', 0.4412942369157319)
#
# Walt Disney Animation Studios was founded by whom?
# ('Walt Disney Animation Studios', 'Q1047410', 'ORGLOC', "one of the Walt Disney Company's animation studios", 2.259711708989656)
#
# What is the catchphrase of the fictional character James Bond?
# ('What', 'Q96980581', 'PERSON', None, 1.5795712003280968)
# ('James Bond', '', 'PERSON', 'American ornithologist and inspiration for the name of the fictional spy', -0.7955484594804251)
#
# What is the main subject of Se7en?
#
# What are the genres of Fargo?
# ('What', 'Q96980581', 'PERSON', None, 0.5491950987628716)
# ('Fargo', '', 'ORG', 'city in North Dakota, United States of America', -0.4950241352041421)
#
# Who are the directors of The Big Lebowski?
#
# Who are Christopher Nolan's children?
# ('Who', 'Q93346', 'ORG', 'English rock band', 0.5147856386178996)
# ("Christopher Nolan's", 'Q25191', 'PERSON', 'English-American film director, screenwriter, and producer', 0.08993881317610863)
#
# Which movies did Jan de Bont direct?
# ('Jan de Bont', 'Q376107', 'PERSON', 'Dutch film director', 0.7473834103617277)
#
# What awards did Alan Rickman receive?
# ('Alan Rickman', 'Q106481', 'PERSON', 'English film, television and stage actor, graphic designer (1946-2016)', 0.4811105407661248)
#
# What are the occupations of John Hamilton?
# ('What', 'Q96980581', 'PERSON', None, 1.933314907027019)
# ('John Hamilton', '', 'PERSON', 'English navy commander (1820–1864)', -0.5785695073380733)
#
# Who wrote the scenario for Wall Street?
# ('Who', 'Q93346', 'ORG', 'English rock band', 0.5244700844244442)
# ('Wall Street', 'Q13677', 'ORG', 'American stock exchange', 0.027836993791160114)
#
# Who are the directors of Shrek?
# ('Shrek', '', 'ORG', 'French professional wrestler', -0.6983467040961605)
#
# What are the main subjects of Inception?
#
# Which countries is the movie O Brother Where Art Thou from?
#
# What gender is Elliot Page?
# ('Elliot Page', '', 'PERSON', 'Canadian actor and producer', -0.037775563823715386)
#
# Name the children of Will Smith.
# ('Name', 'Q1125', 'LOC', 'province in Wallonia, Belgium', 0.1959557234018393)
# ('Will Smith', 'Q40096', 'PERSON', 'American actor, film producer, and rapper', 0.08126663669550827)
#
# How many episodes does The Queen's Gambit have?
# ("The Queen's", 'Q9682', 'PERSON', 'queen of the UK, Canada, Australia, and New Zealand, and head of the Commonwealth of Nations', 0.5656667826555201)
#
# How many children does Brad Pitt have?
# ('Brad Pitt', '', 'PERSON', 'American actor and filmmaker', -0.10875115285279191)
#
# What is the number of screenwriters of the animated adventure film Tarzan?
# ('What', 'Q96980581', 'PERSON', None, 0.5768149425268686)
# ('Tarzan', '', 'PERSON', 'Argentine footballer (1926-2020)', -1.2070889184614149)
#
# How many awards has Marilyn Monroe received?
# ('Marilyn Monroe', '', 'PERSON', 'American actress, model, and singer', -0.15446358307173502)
#
# How many episodes does Friends have?
#
# Who plays the Joker in the movie Joker?
# ('Joker', '', 'PERSON', 'Italian music label', -0.6991542945989637)
# ('Joker', '', 'PERSON', 'Italian music label', -0.7147845925504218)
#
# Who plays The Dude in The Big Lebowski?
#
# When was Evan Almighty released in Germany?
# ('Germany', 'Q183', 'LOC', 'sovereign state in Central Europe', 0.6233876493039917)
#
# When did the TV-series Doctor Who first start?
# ('TV', 'Q672', 'LOC', 'island sovereign state in Oceania', 0.2268376259889865)
# ('first', '', 'ORDINAL', None, None)
#
# What character does Cobie Smulders play in How I Met Your Mother?
# ('Cobie Smulders', 'Q200566', 'PERSON', 'Canadian actress and former model', 0.8671150394392731)
#
# In what films did Anthony Hopkins play Hannibal Lecter?
# ('Anthony Hopkins', 'Q65932', 'PERSON', 'Welsh actor', 0.17092501192046095)
#
# Who won the Oscar for best director in 2020?
# ('Oscar', '', 'PERSON', 'cape', -0.7502704139266243)
# ('director', 'Q2526255', 'PERSON', 'occupation of a person who directs a film', 0.14511436201547856)
# ('2020', '', 'DATE', None, None)
#
# Is The Dawn Wall a documentary film?
# ('The Dawn Wall', '', 'WORK_OF_ART', None, None)
#
# Is Jeff Bridges a cast member of The Wolf of Wall Street?
# ('Jeff Bridges', 'Q174843', 'PERSON', 'American actor, singer-songwriter and producer', 0.3687773830015667)
#
# Did George Clooney win the BAFTA Award for Best Film?
# ('George Clooney', 'Q23844', 'PERSON', 'American actor, filmmaker, and activist', 0.41622182899913607)
# ('BAFTA Award', 'Q159661', 'ORG', 'independent charity', 0.5371294810151296)
#
# Is Shrek a fantasy film?
# ('Shrek', '', 'PERSON', 'French professional wrestler', -0.755202125277541)
#
# Does Eddard Stark have children?
# ('Eddard Stark', '', 'PERSON', None, None)
#
# Is Finn Collins female?
# ('Finn Collins', '', 'PERSON', None, None)
#
# Who is Jeff Bridges?
# ('Jeff Bridges', 'Q174843', 'PERSON', 'American actor, singer-songwriter and producer', 0.002544557384802304)
#
# What is the date of birth of the son of Denzel Washington?
# ('Denzel Washington', 'Q42101', 'PERSON', 'American actor, screenwriter, director and producer', 0.5920621184640039)
#
# What is an aerial shot?
#
# When was the actor Joaquin Phoenix born?
# ('Joaquin Phoenix', 'Q185140', 'PERSON', 'American actor, music video director, producer, musician, and social activist', 0.3696889780406466)
#
# What is the length of Speed?

# %% [markdown]
# ## Conclusion
#
# Using the wikidata_api, some domain specific disambiguation, and entity_ruler for improving recall of NER, seems to work best.
#
# There is also a module for entity linking against dbpedia (https://spacy.io/universe/project/spacy-dbpedia-spotlight), and one could use the same-as relation to go from dbpedia ids to wikidata ids, but the benefits of such an approach are unclear at the moment.
